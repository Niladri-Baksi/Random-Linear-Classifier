# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(0) #for reproducibility: makes the random number predictable:to make sure the same number generated everytime and the code initialized the same everytime

# %%
#<mean,deviation,size> Gaussian distribution
dogs_whisker_length=np.random.normal(loc=5,scale=1,size=10)
dogs_ear_flappiness_index=np.random.normal(loc=8,scale=1,size=10)

# %%
dogs_whisker_length #x less for dogs ~5
dogs_ear_flappiness_index #y more for dogs ~8
# Out:
# array([7.10453344, 8.3869025 , 7.48919486, 6.81936782, 7.97181777,
#        8.42833187, 8.06651722, 8.3024719 , 7.36567791, 7.63725883])

# %%
cats_whisker_length=np.random.normal(loc=8,scale=1,size=10)
cats_ear_flappiness_index=np.random.normal(loc=5,scale=1,size=10)

# %%
cats_whisker_length #x more for cats ~8
cats_ear_flappiness_index #less for cats ~5
# Out:
# array([5.72909056, 5.12898291, 6.13940068, 3.76517418, 5.40234164,
#        4.31518991, 4.12920285, 4.42115034, 4.68844747, 5.05616534])

# %%
plt.scatter(dogs_whisker_length,dogs_ear_flappiness_index,label="Dogs")
plt.scatter(cats_whisker_length,cats_ear_flappiness_index,label="Cats")
plt.xlabel('whisker length')
plt.ylabel('ear flappiness index')
plt.title("Dogs v/s Cats Classification")
plt.legend() #for the markings or references:takes the label
plt.show()
